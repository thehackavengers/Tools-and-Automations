# %% [markdown]
# # Adverse Media Scrapper using GDELT

# %% [markdown]
# # Architecture
# pgsql
#
# ```Watchlist / Entity Master
#         ↓
# Alias Expansion Engine
#         ↓
# GDELT GKG API (Daily / Near-RT)
#         ↓
# Pre-Filter (Themes + Tone)
#         ↓
# Entity Resolution & Context Matching
#         ↓
# Risk Scoring Engine
#         ↓
# Elasticsearch (Index + History)
#         ↓
# Case Management / Alerts / Dashboards

# %% [markdown]
# # Adverse Media Definition

# %%
ADVERSE_THEMES = {
    "CORRUPTION",
    "FRAUD",
    "TERRORISM",
    "SANCTIONS",
    "MONEY_LAUNDERING",
    "ORGANIZED_CRIME",
    "BRIBERY",
    "FINANCIAL_CRIME"
}

NEGATIVE_TONE_THRESHOLD = -2.0

# %% [markdown]
# # Model Data
#
# ``` {
#   "entity_id": "ENT12345",
#   "entity_name": "ABC Exports Pvt Ltd",
#   "matched_alias": "ABC Exports",
#   "article_url": "https://news.site/article123",
#   "source": "Reuters",
#   "published_datetime": "2025-01-14T10:30:00Z",
#   "gdelt_tone": -3.45,
#   "gdelt_themes": ["CORRUPTION", "FRAUD"],
#   "locations": ["India"],
#   "risk_score": 82,
#   "risk_level": "HIGH",
#   "explanation": "Negative tone with corruption & fraud themes",
#   "ingestion_date": "2025-01-15",
#   "raw_gdelt_record": { }
# }

# %% [markdown]
# # Data extraction Pipeline

# %%
import requests
from datetime import datetime

def fetch_gdelt_gkg(query, start_dt, end_dt, timeout=30):
    url = "https://api.gdeltproject.org/api/v2/gkgv2"
    params = {
        "query": query,
        "mode": "GKG",
        "format": "json",
        "startdatetime": start_dt,
        "enddatetime": end_dt,
        "maxrecords": 250
    }
    resp = requests.get(url, params=params, timeout=timeout)
    resp.raise_for_status()
    return resp.json().get("gkgRecords", [])

# %%
results = fetch_gdelt_gkg("Acme Bank", "20250101000000", "20250131235959")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results = fetch_gdelt_gkg("Acme Bank", "20250101000000", "20250131235959")
#
# Cell In[2], line 15, in fetch_gdelt_gkg(query, start_dt, end_dt, timeout)
#       6 params = {
#       7     "query": query,
#       8     "mode": "GKG",
#    (...)
#      12     "maxrecords": 250
#      13 }
#      14 resp = requests.get(url, params=params, timeout=timeout)
# ---> 15 resp.raise_for_status()
#      16 return resp.json().get("gkgRecords", [])
#
# File ~/Tools and Automations/am_venv/lib/python3.10/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.gdeltproject.org/api/v2/gkgv2?query=Acme+Bank&mode=GKG&format=json&startdatetime=20250101000000&enddatetime=20250131235959&maxrecords=250

# %% [markdown]
# # Alias Expansion (Critical for FIU Accuracy)
# Example:
#
# ``` entity = {
#     "entity_id": "ENT001",
#     "name": "ABC Exports Pvt Ltd",
#     "aliases": ["ABC Exports", "ABC Exporters", "ABC Exports India"]
# }

# %%
def generate_alias_query(entity):
    aliases = entity["aliases"]
    return " OR ".join([f'"{a}"' for a in aliases])

# %%
# Adverse Media Filter
def is_adverse(record):
    tone = float(record.get("Tone", 0))
    themes = set(record.get("Themes", "").split(";"))

    adverse_theme_hit = bool(themes & ADVERSE_THEMES)
    negative_tone_hit = tone <= NEGATIVE_TONE_THRESHOLD

    return adverse_theme_hit or negative_tone_hit

# %%
#Risk Scoring Engine (Explainable)
def calculate_risk_score(record):
    score = 0
    tone = abs(float(record.get("Tone", 0)))
    themes = set(record.get("Themes", "").split(";"))

    score += min(tone * 5, 30)              # Sentiment impact
    score += len(themes & ADVERSE_THEMES) * 15
    score += 10 if "SANCTIONS" in themes else 0

    return min(score, 100)

# %%
#Normalize Record for Elasticsearch
def normalize_record(entity, record, score):
    return {
        "entity_id": entity["entity_id"],
        "entity_name": entity["name"],
        "matched_alias": entity["name"],
        "article_url": record.get("DocumentIdentifier"),
        "published_datetime": record.get("Date"),
        "gdelt_tone": float(record.get("Tone", 0)),
        "gdelt_themes": record.get("Themes", "").split(";"),
        "risk_score": score,
        "risk_level": "HIGH" if score >= 70 else "MEDIUM",
        "explanation": "Automated adverse media detection via GDELT",
        "raw_gdelt_record": record
    }

# %%
# Elasticsearch Ingestion (Bulk-Safe)
from elasticsearch import Elasticsearch, helpers

es = Elasticsearch(
    "https://localhost:9200",
    basic_auth=("elastic", "password"),
    verify_certs=False
)

def bulk_ingest(records):
    actions = [
        {
            "_index": "fiu_adverse_media",
            "_source": r
        }
        for r in records
    ]
    helpers.bulk(es, actions)

# %% [markdown]
# # Known GDELT Limitations (and Fixes)
# ```
# | Limitation           | Mitigation                         |
# | -------------------- | ---------------------------------- |
# | False positives      | Entity proximity + alias weighting |
# | No article full text | Fetch URL separately               |
# | Over-broad themes    | Custom FIU theme whitelist         |
# | No legal judgment    | Human review loop                  |

# %% [markdown]
# # 9️⃣ How FIUs Commonly Use This
# ```
# ✅ AML onboarding checks
# ✅ Sanction evasion monitoring
# ✅ Politically exposed person (PEP) monitoring
# ✅ Trade-based money laundering (TBML) risk
# ✅ Counter-terror financing (CTF)

# %%
import pandas as pd
import re

# %%
df1 = pd.read_csv('./output/final_adverse_media_June_2025.csv')
df2 = pd.read_csv('./output/final_adverse_media_July_2025.csv')
df3 = pd.read_csv('./output/final_adverse_media_Aug_2025.csv')
df4 = pd.read_csv('./output/final_adverse_media_Sep_2025.csv')
df5 = pd.read_csv('./output/final_adverse_media_Oct_2025.csv')
df_list = [df1, df2, df3, df4, df5]
df = pd.concat(df_list).reset_index(drop=True)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://timesofindia.indiatimes.com/city/vadod...
# 1  https://www.newindianexpress.com/nation/2025/J...
# 2  https://www.tribuneindia.com/news/jalandhar/no...
# 3  https://timesofindia.indiatimes.com/web-series...
# 4  https://timesofindia.indiatimes.com/city/ranch...
#
#                                           url_mobile  \
# 0  https://timesofindia.indiatimes.com/city/vadod...
# 1  https://www.newindianexpress.com/amp/story/nat...
# 2  https://www.tribuneindia.com/news/jalandhar/no...
# 3  https://timesofindia.indiatimes.com/web-series...
# 4  https://timesofindia.indiatimes.com/city/ranch...
#
#                                                title      date  \
# 0  NREGA scam : Minister sons sent to judicial cu...  20250606
# 1    Missing  wife of Indore man found dead on ho...  20250609
# 2          No relief for MLA Arora son - The Tribune  20250607
# 3    Rick and Morty  season 8 : Episode 3 highlig...  20250609
# 4  Bokaro villagers stir against sand mining | Ra...  20250609
#
#                                          socialimage  \
# 0  https://static.toiimg.com/thumb/msid-121683107...
# 1  https://media.assettype.com/newindianexpress%2...
# 2  https://www.tribuneindia.com/sortd-service/ima...
# 3  https://static.toiimg.com/thumb/msid-121719119...
# 4  https://static.toiimg.com/thumb/msid-117692178...
#
#                         domain language sourcecountry  \
# 0  timesofindia.indiatimes.com  English         India
# 1         newindianexpress.com  English         India
# 2             tribuneindia.com  English         India
# 3  timesofindia.indiatimes.com  English         India
# 4  timesofindia.indiatimes.com  English         India
#
#                                              article  \
# 0  Vadodara: Balwant and Kiran Khabad, the sons o...
# 1  In a major development in the case of the miss...
# 2  The court of Special Judge Jaswinder Singh on ...
# 3  What happened in episode 3 of 'Rick and Morty'...
# 4  Bokaro: Residents of several villages, led by ...
#
#                                              quantum lea  \
# 0                                                 []  []
# 1                                                 []  []
# 2  ['Rs 12 crore', 'Rs 60 lakh', 'Rs 10 crore', '...  []
# 3                                                 []  []
# 4                                                 []  []
#
#                     crimes                                             person  \
# 0                 ['scam']  {'rasik rathwa', 'rathwa', 'kiran', 'bhanpur',...
# 1               ['murder']  {'xraja raghuvanshi', 'sonam raghuvanshi', 'gh...
# 2  ['bribe', 'corruption']  {'rajan arora', 'aroras', 'darshan singh dyal'...
# 3               ['kidnap']  {'sarah chalke', 'doc morty', 'keith david', '...
# 4       ['illegal mining']  {'ravi kumar singh', 'mamarkudar', 'chas', 'yu...
#
#                locations                                         Keywords
# 0     ['Dahod district']              case, nrega, kiran, friday, balwant
# 1  ['Ghazipur district']  meghalaya, sonam, police, arrested, raghuvanshi
# 2                     []           accused, mla, notices, vashisht, arora
# 3                     []            episode, rick, release, morty, season
# 4                     []              mining, water, sand, villages, said

# %%
df.columns
# Out:
# Index(['url', 'url_mobile', 'title', 'date', 'socialimage', 'domain',
#        'language', 'sourcecountry', 'article', 'quantum', 'lea', 'crimes',
#        'person', 'locations', 'Keywords'],
#       dtype='object')

# %%
import re

# function to convert list, set to text 
def list_to_text(text: str) -> str:
    return re.sub(r"[{}\[\]()\"']", "", text).replace("set", "").strip()

# %%
df.tail()
# Out:
#                                                      url  \
# 12080  https://www.moneycontrol.com/news/india/rahul-...
# 12081  https://www.news18.com/india/bhojpuri-actor-yo...
# 12082  https://www.tribuneindia.com/news/delhi/two-yo...
# 12083  https://www.livelaw.in/high-court/bombay-high-...
# 12084  https://aninews.in/news/business/mastercard-in...
#
#                                               url_mobile  \
# 12080  https://www.moneycontrol.com/news/india/rahul-...
# 12081  https://www.news18.com/amp/india/bhojpuri-acto...
# 12082  https://www.tribuneindia.com/news/delhi/two-yo...
# 12083  https://www.livelaw.in/amp/high-court/bombay-h...
# 12084  /news/business/mastercard-introduces-first-eve...
#
#                                                    title      date  \
# 12080  Rahul  dance  taunt not the first : How person...  20251030
# 12081  Bhojpuri Actor , YouTuber Mani Meraj Arrested ...  20251006
# 12082                 Two youths linked to ISIS arrested  20251025
# 12083  Bombay High Court Seeks SEBI Response In Plea ...  20251006
# 12084  Mastercard introduces first - ever threat inte...  20251029
#
#                                              socialimage            domain  \
# 12080  https://images.moneycontrol.com/static-mcnews/...  moneycontrol.com
# 12081  https://images.news18.com/ibnlive/uploads/2025...        news18.com
# 12082  https://www.tribuneindia.com/sortd-service/ima...  tribuneindia.com
# 12083  https://www.livelaw.in/h-upload/2025/10/06/624...        livelaw.in
# 12084  https://d3lzcn6mbbadaf.cloudfront.net/media/de...        aninews.in
#
#       language sourcecountry  \
# 12080  English         India
# 12081  English         India
# 12082  English         India
# 12083  English         India
# 12084  English         India
#
#                                                  article           quantum  \
# 12080  Returning from a 58-day hiatus from the Bihar ...                []
# 12081  Bhojpuri Actor, YouTuber Mani Meraj Arrested I...                []
# 12082  Two youths allegedly linked to banned terror o...                []
# 12083  A petition has been filed in the Bombay High C...                []
# 12084  PRNewswire\n\nSingapore, October 29: Today, Ma...  ['$120 million']
#
#                                                      lea             crimes  \
# 12080                                                 []                 []
# 12081                                                 []  ['fraud', 'drug']
# 12082                                                 []                 []
# 12083  ['SECURITIES AND EXCHANGE BOARD OF INDIA', '(S...                 []
# 12084                                                 []          ['fraud']
#
#                                                   person  \
# 12080  {'behrampura', 'modi', 'rahul gandhi', 'chhath...
# 12081  {'pinky chaudhary', 'mani meraj', 'youtuber', ...
# 12082  {'mohammad adnan khan', 'abu muharib', 'sadiq ...
# 12083                                   {'vinay bansal'}
# 12084                                 {'matthew driver'}
#
#                               locations  \
# 12080                                []
# 12081                                []
# 12082                                []
# 12083                                []
# 12084  ['Asia-Pacific', 'Asia Pacific']
#
#                                              Keywords
# 12080                   modi, congress, pm, bjp, said
# 12081          meraj, police, youtuber, mani, accused
# 12082            isis, delhi, said, arrested, handler
# 12083      india, offer, management, limited, accused
# 12084  intelligence, fraud, mastercard, threat, cyber

# %%
########################################################
#Function to prepare data for uploading in DB
########################################################
from datetime import date, datetime

def prepare_for_db(df):
    #droping duplicate on url
    df = df.drop_duplicates(subset='url')
    # adding unique ARN
    df = df.reset_index()
    today = date.today().strftime('%Y%m%d')
    df['ARN'] = 'ARN'+today+df['index'].astype('str')
    df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')

    columns = ['ARN', 'date', 'title', 'article', 'domain', 'url', 'lea', 'crimes',
        'person', 'locations', 'quantum', 'Keywords' ]
    df = df[columns]
    # fixing list columns
    list_columns = ['lea', 'crimes', 'person', 'locations', 'quantum', 'Keywords' ]
    for col in list_columns:
        df[col] = df[col].astype('str').map(lambda x: list_to_text(x))
    return df

# %%
df = prepare_for_db(df)

# %%
df.head()
# Out:
#             ARN       date                                              title  \
# 0  ARN202601260 2025-06-06  NREGA scam : Minister sons sent to judicial cu...
# 1  ARN202601261 2025-06-09    Missing  wife of Indore man found dead on ho...
# 2  ARN202601262 2025-06-07          No relief for MLA Arora son - The Tribune
# 3  ARN202601263 2025-06-09    Rick and Morty  season 8 : Episode 3 highlig...
# 4  ARN202601264 2025-06-09  Bokaro villagers stir against sand mining | Ra...
#
#                                              article  \
# 0  Vadodara: Balwant and Kiran Khabad, the sons o...
# 1  In a major development in the case of the miss...
# 2  The court of Special Judge Jaswinder Singh on ...
# 3  What happened in episode 3 of 'Rick and Morty'...
# 4  Bokaro: Residents of several villages, led by ...
#
#                         domain  \
# 0  timesofindia.indiatimes.com
# 1         newindianexpress.com
# 2             tribuneindia.com
# 3  timesofindia.indiatimes.com
# 4  timesofindia.indiatimes.com
#
#                                                  url lea             crimes  \
# 0  https://timesofindia.indiatimes.com/city/vadod...                   scam
# 1  https://www.newindianexpress.com/nation/2025/J...                 murder
# 2  https://www.tribuneindia.com/news/jalandhar/no...      bribe, corruption
# 3  https://timesofindia.indiatimes.com/web-series...                 kidnap
# 4  https://timesofindia.indiatimes.com/city/ranch...         illegal mining
#
#                                               person          locations  \
# 0  rasik rathwa, rathwa, kiran, bhanpur, nagori, ...     Dahod district
# 1  xraja raghuvanshi, sonam raghuvanshi, ghazipur...  Ghazipur district
# 2  rajan arora, aroras, darshan singh dyal, raman...
# 3  sarah chalke, doc morty, keith david, the arca...
# 4  ravi kumar singh, mamarkudar, chas, yudhistar ...
#
#                                             quantum  \
# 0
# 1
# 2  Rs 12 crore, Rs 60 lakh, Rs 10 crore, Rs 39 lakh
# 3
# 4
#
#                                           Keywords
# 0              case, nrega, kiran, friday, balwant
# 1  meghalaya, sonam, police, arrested, raghuvanshi
# 2           accused, mla, notices, vashisht, arora
# 3            episode, rick, release, morty, season
# 4              mining, water, sand, villages, said

# %%
from db.db_manager import AdverseMediaDB

def store_to_sqlite(df_final):
    db = AdverseMediaDB()
    db.create_table()
    db.insert_dataframe(df_final)

# %%
store_to_sqlite(df)

# %%
df.head()
# Out:
#    level_0  index       date  \
# 0        0      0 2025-06-06
# 1        1      1 2025-06-09
# 2        2      2 2025-06-07
# 3        3      3 2025-06-09
# 4        4      4 2025-06-09
#
#                                                title  \
# 0  NREGA scam : Minister sons sent to judicial cu...
# 1    Missing  wife of Indore man found dead on ho...
# 2          No relief for MLA Arora son - The Tribune
# 3    Rick and Morty  season 8 : Episode 3 highlig...
# 4  Bokaro villagers stir against sand mining | Ra...
#
#                                              article  \
# 0  Vadodara: Balwant and Kiran Khabad, the sons o...
# 1  In a major development in the case of the miss...
# 2  The court of Special Judge Jaswinder Singh on ...
# 3  What happened in episode 3 of 'Rick and Morty'...
# 4  Bokaro: Residents of several villages, led by ...
#
#                         domain  \
# 0  timesofindia.indiatimes.com
# 1         newindianexpress.com
# 2             tribuneindia.com
# 3  timesofindia.indiatimes.com
# 4  timesofindia.indiatimes.com
#
#                                                  url lea  \
# 0  https://timesofindia.indiatimes.com/city/vadod...  []
# 1  https://www.newindianexpress.com/nation/2025/J...  []
# 2  https://www.tribuneindia.com/news/jalandhar/no...  []
# 3  https://timesofindia.indiatimes.com/web-series...  []
# 4  https://timesofindia.indiatimes.com/city/ranch...  []
#
#                     crimes                                             person  \
# 0                 ['scam']  {'rasik rathwa', 'rathwa', 'kiran', 'bhanpur',...
# 1               ['murder']  {'xraja raghuvanshi', 'sonam raghuvanshi', 'gh...
# 2  ['bribe', 'corruption']  {'rajan arora', 'aroras', 'darshan singh dyal'...
# 3               ['kidnap']  {'sarah chalke', 'doc morty', 'keith david', '...
# 4       ['illegal mining']  {'ravi kumar singh', 'mamarkudar', 'chas', 'yu...
#
#                locations                                            quantum  \
# 0     ['Dahod district']                                                 []
# 1  ['Ghazipur district']                                                 []
# 2                     []  ['Rs 12 crore', 'Rs 60 lakh', 'Rs 10 crore', '...
# 3                     []                                                 []
# 4                     []                                                 []
#
#                                           Keywords           ARN
# 0              case, nrega, kiran, friday, balwant  ARN202601230
# 1  meghalaya, sonam, police, arrested, raghuvanshi  ARN202601231
# 2           accused, mla, notices, vashisht, arora  ARN202601232
# 3            episode, rick, release, morty, season  ARN202601233
# 4              mining, water, sand, villages, said  ARN202601234

# %%
from datetime import datetime
import sqlite3

def generate_arn_id(df):
    """
    Generates ARN + YYYYMMDD + 4-digit daily auto-increment
    Example: ARN202601230001
    """
    today = datetime.utcnow().strftime('%Y%m%d')
    cursor = conn.cursor()

    cursor.execute("""
        SELECT id
        FROM adverse_media
        WHERE SUBSTR(id, 4, 8) = ?
        ORDER BY id DESC
        LIMIT 1
    """, (today,))

    row = cursor.fetchone()

    if row:
        last_seq = int(row[0][-4:])
        next_seq = last_seq + 1
    else:
        next_seq = 1

    arn_id = f"ARN{today}{next_seq:04d}"
    return arn_id

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2026, 1, 26, 17, 11, 21, 587537)

# %%
datetime.now().strftime("%Y%m%d%H%M%S")
# Out:
# '20260126171444'

# %%
date.today().strftime("%Y-%m-%d")
# Out:
# '2026-01-26'
